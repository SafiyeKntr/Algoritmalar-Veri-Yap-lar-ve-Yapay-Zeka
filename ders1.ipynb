# %% [markdown]
# -18.04.2026-
#
# İYC Genel Merkez
#
# Veri Bilimi Eğitimi
#
# Eğitmen: Ali Çetinkaya
#
# Saat: 10.00-17.00
# #### "Veriyi işle geleceği kodla"

# %%
print("Selamünaleyküm, dünya! :))")
# Out:
# Selamünaleyküm, dünya! :))

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/GoogleColab')
# !pwd # ilk kodun çıktısını veren blok
# Out:
# /content/drive/My Drive/GoogleColab
